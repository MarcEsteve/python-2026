# %% [markdown]
# # Lectura de documentos Word .docx

# %%
import docx

# %%
ruta= 'C:/Users/artha/OneDrive/Escritorio/AKKODIS/python-rda/05_xlsx_docx_pdf/tecnologias_emergentes.docx' #Cargamos el documento docx

# %%
d = docx.Document(ruta) #Lista con los párrafos del documento

# %%
d.paragraphs #Texto del primer párrafo
# Out:
# [<docx.text.paragraph.Paragraph at 0x2d9b7e0e3f0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0d9a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f020>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e900>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f5c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c980>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e6f0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0cd40>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e120>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c500>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0cb90>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0df70>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c770>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e0c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c4a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c6e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c5c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0d430>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0cc50>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0dc10>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0dd60>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0d520>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0ddc0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e360>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c5f0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e030>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e3c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e000>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e1e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e780>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0db80>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e300>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e570>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0daf0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c710>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0db50>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c830>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0c1a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0ec90>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f7a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f830>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f3e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0fa10>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f4d0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0fa40>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0e8d0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0ff80>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0ffe0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f4a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0cc20>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0fce0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e0f9b0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e349e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34a40>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e342c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34470>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34830>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34c20>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34cb0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34ce0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34050>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e340b0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34110>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34170>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e341d0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34260>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e342f0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34380>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e343e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34440>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e344d0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34560>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e345c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34620>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34680>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e346e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34740>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e347a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34800>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34890>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e348f0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34950>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e349b0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34aa0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34b00>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34b60>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34d40>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34da0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34e00>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34e60>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34ec0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34f20>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34f80>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e34fe0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35040>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e350a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35100>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35160>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e351c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35220>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35280>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e352e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35340>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e353a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35400>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35460>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e354c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35520>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35580>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e355e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35640>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e356a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35700>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35760>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e357c0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35820>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35880>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e358e0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35940>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e359a0>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35a00>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35a60>,
#  <docx.text.paragraph.Paragraph at 0x2d9b7e35ac0>]

# %%
d.paragraphs[0].text
# Out:
# 'Tecnologías Emergentes 2025'

# %%
p= d.paragraphs[2]

# %%
p.runs[0].text
# Out:
# '“'

# %%
p.runs[1].text
# Out:
# 'El año 2025 marcará un punto de inflexión en la '

# %%
p.runs[2].text
# Out:
# 'evolución de diversas tecnologías emergentes'

# %%
p.runs[4].text
# Out:
# '”'

# %%
#Lectura completa
def coger_texto(fichero):
    doc= docx.Document(fichero)
    texto_completo = []
    for parrafo in doc.paragraphs:
        texto_completo.append(parrafo.text)
    return "\n".join(texto_completo)

print(coger_texto(ruta))
# Out:
# Tecnologías Emergentes 2025
# Introducción
# “El año 2025 marcará un punto de inflexión en la evolución de diversas tecnologías emergentes.”
# Con avances significativos en inteligencia artificial, computación cuántica, biotecnología y sostenibilidad, las empresas y la sociedad en general experimentarán cambios transformadores.
# Este documento explora las principales innovaciones que se esperan en los próximos años y su impacto en la economía global.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Inteligencia Artificial (IA) y Automatización
# La inteligencia artificial seguirá revolucionando sectores como la salud, la educación y la industria. Modelos avanzados de IA generativa permitirán una interacción más natural entre humanos y máquinas, mientras que la automatización impulsada por IA optimizará la eficiencia en tareas complejas. Se espera que:
# Las herramientas de IA se integren más en el ámbito educativo, personalizando el aprendizaje.
# La robótica avanzada en la medicina mejore los procedimientos quirúrgicos y la atención al paciente.
# Los algoritmos predictivos permitan una mejor gestión de recursos en sectores como la energía y el transporte.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Computación Cuántica
# La computación cuántica avanza a pasos agigantados, con empresas tecnológicas invirtiendo en el desarrollo de procesadores cuánticos más estables y accesibles. En 2025, se prevé:
# Mayor integración de la computación cuántica en la resolución de problemas logísticos y financieros.
# Avances en criptografía cuántica para mejorar la seguridad en la transmisión de datos.
# Simulaciones moleculares más precisas, acelerando el descubrimiento de nuevos materiales y fármacos.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Biotecnología y Medicina Personalizada
# El desarrollo de la biotecnología permitirá tratamientos más efectivos y personalizados para diversas enfermedades. La combinación de IA y biología sintética posibilitará avances como:
# Terapias génicas más accesibles y con menores efectos secundarios.
# Diagnósticos médicos en tiempo real mediante sensores y dispositivos portátiles.
# Impresión 3D de tejidos y órganos para mejorar la disponibilidad de trasplantes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sostenibilidad y Energías Renovables
# Con la crisis climática en el centro del debate mundial, 2025 será un año clave para la transición energética y el desarrollo de soluciones más sostenibles. Entre los avances más esperados destacan:
# Mayor eficiencia en el almacenamiento de energía con baterías de nueva generación.
# Uso masivo de hidrógeno verde como fuente de energía limpia.
# Aplicación de nanotecnología para mejorar la captura y reutilización de CO2.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Conclusión
# El impacto de estas tecnologías en la sociedad dependerá de cómo sean reguladas e implementadas. La colaboración entre gobiernos, empresas y científicos será clave para asegurar un desarrollo tecnológico ético y sostenible. 2025 promete ser un año de innovaciones que cambiarán la forma en que vivimos y trabajamos, abriendo nuevas oportunidades y desafíos para el futuro.

# %%
# Coger texto sin líneas vacías
def coger_texto(fichero):
    doc = docx.Document(fichero)
    texto_completo = []
    
    for parrafo in doc.paragraphs:
        texto = parrafo.text.strip()  # Eliminar espacios y saltos de línea al inicio y al final
        
        if texto:  # Solo agregamos el párrafo si no está vacío
            texto_completo.append(texto)
    
    return "\n\n".join(texto_completo)  # Usar doble salto de línea para mejor separación

# %%
print(coger_texto(ruta))
# Out:
# Tecnologías Emergentes 2025
#
# Introducción
#
# “El año 2025 marcará un punto de inflexión en la evolución de diversas tecnologías emergentes.”
#
# Con avances significativos en inteligencia artificial, computación cuántica, biotecnología y sostenibilidad, las empresas y la sociedad en general experimentarán cambios transformadores.
#
# Este documento explora las principales innovaciones que se esperan en los próximos años y su impacto en la economía global.
#
# Inteligencia Artificial (IA) y Automatización
#
# La inteligencia artificial seguirá revolucionando sectores como la salud, la educación y la industria. Modelos avanzados de IA generativa permitirán una interacción más natural entre humanos y máquinas, mientras que la automatización impulsada por IA optimizará la eficiencia en tareas complejas. Se espera que:
#
# Las herramientas de IA se integren más en el ámbito educativo, personalizando el aprendizaje.
#
# La robótica avanzada en la medicina mejore los procedimientos quirúrgicos y la atención al paciente.
#
# Los algoritmos predictivos permitan una mejor gestión de recursos en sectores como la energía y el transporte.
#
# Computación Cuántica
#
# La computación cuántica avanza a pasos agigantados, con empresas tecnológicas invirtiendo en el desarrollo de procesadores cuánticos más estables y accesibles. En 2025, se prevé:
#
# Mayor integración de la computación cuántica en la resolución de problemas logísticos y financieros.
#
# Avances en criptografía cuántica para mejorar la seguridad en la transmisión de datos.
#
# Simulaciones moleculares más precisas, acelerando el descubrimiento de nuevos materiales y fármacos.
#
# Biotecnología y Medicina Personalizada
#
# El desarrollo de la biotecnología permitirá tratamientos más efectivos y personalizados para diversas enfermedades. La combinación de IA y biología sintética posibilitará avances como:
#
# Terapias génicas más accesibles y con menores efectos secundarios.
#
# Diagnósticos médicos en tiempo real mediante sensores y dispositivos portátiles.
#
# Impresión 3D de tejidos y órganos para mejorar la disponibilidad de trasplantes.
#
# Sostenibilidad y Energías Renovables
#
# Con la crisis climática en el centro del debate mundial, 2025 será un año clave para la transición energética y el desarrollo de soluciones más sostenibles. Entre los avances más esperados destacan:
#
# Mayor eficiencia en el almacenamiento de energía con baterías de nueva generación.
#
# Uso masivo de hidrógeno verde como fuente de energía limpia.
#
# Aplicación de nanotecnología para mejorar la captura y reutilización de CO2.
#
# Conclusión
#
# El impacto de estas tecnologías en la sociedad dependerá de cómo sean reguladas e implementadas. La colaboración entre gobiernos, empresas y científicos será clave para asegurar un desarrollo tecnológico ético y sostenible. 2025 promete ser un año de innovaciones que cambiarán la forma en que vivimos y trabajamos, abriendo nuevas oportunidades y desafíos para el futuro.

# %% [markdown]
# # Edición

# %%
p.runs[1].bold = True #Negrita, para cursiva seria italic y underline para subrayado, por ejemplo

# %%
p.runs[2].text = 'otro texto' #Cambiamos el texto del segundo run del párrafo p

# %%
d.save(r'C:/Users/artha/OneDrive/Escritorio/AKKODIS/python-2026/02_xlsx_docx_pdf/tecnologias_emergentes_v2.docx') #Guardamos el documento

# %% [markdown]
# # Creación de ficheros

# %%
nuevo_d = docx.Document() #Creamos un documento en blanco

# %%
nuevo_d.add_paragraph('Este es el primer párrafo de mi documento')

# %%
nuevo_d.add_paragraph('Este es el segundo párrafo de mi documento')

# %%
nuevo_d.save(r'C:/Users/artha/OneDrive/Escritorio/AKKODIS/python-2026/02_xlsx_docx_pdf/nuevo_documento.docx') #Guardamos el documento

# %%
p = nuevo_d.paragraphs[0] #Cogemos el primer párrafo
p.add_run('Este es un nuevo segmento añadido al primer párrafo') #Añadimos un nuevo segmento al párrafo
p.runs[1].underline = True #Subrayamos el nuevo segmento
nuevo_d.save(r'C:/Users/artha/OneDrive/Escritorio/AKKODIS/python-2026/02_xlsx_docx_pdf/nuevo_documento.docx') #Guardamos el documento
