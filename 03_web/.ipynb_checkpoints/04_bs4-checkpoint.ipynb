# %% [markdown]
# # Web Scrapping BeautifulSoup

# %%
import bs4 # Importamos la librería BeautifulSoup
import requests # Importamos la librería requests
import lxml # Importamos la librería lxml

# %% [markdown]
# ### La "cabecera" se lo explicamos al navegador como si fueramos un humano y no un bot

# %%
cabecera = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
}

# %% [markdown]
# ### Objetivo: Obtener el precio de la página web milanuncios de un Tesla como ejemplo

# %% [markdown]
# ### Ejemplo1 Tesla Y

# %%
url = "https://www.milanuncios.com/tesla-de-segunda-mano/tesla-model-y-582552852.htm"

# %%
response = requests.get(url, headers=cabecera)

# %%
response.status_code
# Out:
# 200

# %%
soup = bs4.BeautifulSoup(response.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><title data-rh="">Milanuncios - TESLA - Model Y</title><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" data-rh="" name="viewport"/><meta content="index, follow, max-snippet:-1, max-image-preview:large" data-rh="" name="robots"/><meta content="TESLA - Model Y Precio financiado sujeto a financiaciÓn mÍnima de 30.000€ en 72 meses y permanencia de 24 meses
#
#  subjecte a finanÇament mÍnim de 30.000 € en 72 mesos i permenencia 24 mesos Tarragona Tarragona" data-rh="" name="description"/><meta content="https://www.milanuncios.com/tesla-de-segunda-mano/tesla-model-y-582552852.htm" data-rh="" property="og:url"/><meta content="product" data-rh="" property="og:type"/><meta content="TESLA - Model Y" data-rh="" property="og:title"/><meta content="Precio financiado sujeto a financiaciÓn mÍnima de 30.000€ en 72 meses y permanencia de 24 meses
#
#  subjecte a finanÇament mÍnim de 30.000 € en 72 mesos i permenencia 24 mesos" data-rh="" property="og:description"/><meta content="https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=hw396" data-rh="" property="og:image"/><meta content="https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=hw396" data-rh="" property="og:image:secure_url"/><meta content="640" data-rh="" property="og:image:width"/><link data-rh="" href="https://www.milanuncios.com/tesla-de-segunda-mano/tesla-model-y-582552852.htm" rel="canonical"/><link as="image" data-rh="" href="https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_640x480" imagesizes="(min-width: 1200px) 640px, (min-width: 960px) 640px, (min-width: 840px) 596px, (min-width: 480px) 432px, calc(100vw - 32px)" imagesrcset="https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_640x480 640w, https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_596x447 596w, https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_432x320 432w" rel="preload"/><link href="https://scm-milanuncios-frontend-pro.milanuncios.com/spa/AppStyles.6cb1d28c.css" rel="stylesheet"/><link href="https://scm-milanuncios-frontend-pro.milanuncios.com/spa/ClassifiedDetail.ececef42.css" rel="stylesheet"/><meta content="width=device-width,initial-scale=1,shrink-to-fit=no" name="viewport"/><link href="https://scm-milanuncios-frontend-pro.milanuncios.com" rel="preconnect dns-prefetch"/><link href="https://api.segment.io" rel="preconnect dns-prefetch"/><link href="https://cdn.segment.com" rel="preconnect dns-prefetch"/><link href="https://logx.optimizely.com" rel="preconnect dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="preconnect dns-prefetch"/><link href="https://www.googletagmanager.com" rel="preconnect dns-prefetch"/><link as="font" crossorigin="" href="https://scm-milanuncios-frontend-pro.milanuncios.com/statics/fonts/rubik/rubik-variable.woff2" rel="preload" type="font/woff2"/><!-- Didomi STUB --><script type="text/javascript">(function(){function i(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}else{setTimeout(function(){i(e)},5)}}}function e(n,o,r,f,s){function e(e,t,n,i){if(typeof n!=="function"){return}if(!window[o]){window[o]=[]}var a=false;if(s){a=s(e,i,n)}if(!a){window[o].push({command:e,version:t,callback:n,parameter:i})}}e.stub=true;e.stubVersion=2;function t(i){if(!window[n]||window[n].stub!==true){return}if(!i.data){return}var a=typeof i.data==="string";var e;try{e=a?JSON.parse(i.data):i.data}catch(t){return}if(e[r]){var o=e[r];window[n](o.command,o.version,function(e,t){var n={};n[f]={returnValue:e,success:t,callId:o.callId};if(i.source){i.source.postMessage(a?JSON.stringify(n):n,"*")}},o.parameter)}}if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");i("__tcfapiLocator")})();</script><meta content="#30923e" name="theme-color"/><!-- Custom metas --><meta content="" name="x-server-version"/><meta content="production" name="x-server-env"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="Milanuncios" name="apple-mobile-web-app-title"/><meta content="sites-8458572526714869" name="google-adsense-account"/><meta content="" name="csrf-token"/><link href="https://scm-milanuncios-frontend-pro.milanuncios.com/statics/images/icons/icon-square-72x72.png" rel="apple-touch-icon"/><link href="ht ...
#     var siteKeys={production:"XIorQ13qoWZPxgFwh2uAoTTiWoi5XhQq",development:"C59D603OtzyQI6fq2l607bOJxlFsGFY7"},writeKey=siteKeys["production"]||siteKeys.development;
#     if(window.document.location.href.match('disable-tealium')||window.sessionStorage.getItem('disable-tealium'))return null;}}();</script><script defer="" src="https://www.milanuncios.com/librarym.js"></script><script>!function(){"use strict";var e,a,t,s,r={},c={};function d(e){var a=c[e];if(void 0!==a)return a.exports;var t=c[e]={id:e,loaded:!1,exports:{}};return r[e].call(t.exports,t,t.exports,d),t.loaded=!0,t.exports}d.m=r,d.amdO={},e=[],d.O=function(a,t,s,r){if(!t){var c=1/0;for(f=0;f<e.length;f++){t=e[f][0],s=e[f][1],r=e[f][2];for(var o=!0,i=0;i<t.length;i++)(!1&r||c>=r)&&Object.keys(d.O).every(function(e){return d.O[e](t[i])})?t.splice(i--,1):(o=!1,r<c&&(c=r));if(o){e.splice(f--,1);var n=s();void 0!==n&&(a=n)}}return a}r=r||0;for(var f=e.length;f>0&&e[f-1][2]>r;f--)e[f]=e[f-1];e[f]=[t,s,r]},d.n=function(e){var a=e&&e.__esModule?function(){return e.default}:function(){return e};return d.d(a,{a:a}),a},t=Object.getPrototypeOf?function(e){return Object.getPrototypeOf(e)}:function(e){return e.__proto__},d.t=function(e,s){if(1&s&&(e=this(e)),8&s)return e;if("object"==typeof e&&e){if(4&s&&e.__esModule)return e;if(16&s&&"function"==typeof e.then)return e}var r=Object.create(null);d.r(r);var c={};a=a||[null,t({}),t([]),t(t)];for(var o=2&s&&e;"object"==typeof o&&!~a.indexOf(o);o=t(o))Object.getOwnPropertyNames(o).forEach(function(a){c[a]=function(){return e[a]}});return c.default=function(){return e},d.d(r,c),r},d.d=function(e,a){for(var t in a)d.o(a,t)&&!d.o(e,t)&&Object.defineProperty(e,t,{enumerable:!0,get:a[t]})},d.f={},d.e=function(e){return Promise.all(Object.keys(d.f).reduce(function(a,t){return d.f[t](e,a),a},[]))},d.u=function(e){return({22:"GetTmxSessionIdAuthenticationUseCaseFactory",35:"GetFormBuilderJsonSearchUseCase",48:"GetAdSearchParamsFromFormBuilderSearchUseCase",57:"DeleteFavoriteAdV2UserUseCase",73:"LogoutUserUseCaseFactory",111:"SaveFavoriteAdUserUseCaseFactory",249:"ObsoleteAd",268:"SeoBackwebUseCasesFactory",297:"DAC7Page",387:"GetUserTransactionsUserUseCaseFactory",458:"GetFavoritesStateChangedAdsSearchUseCase",494:"GetFormBuilderLocationSearchUseCase",515:"GetSelectedCategoryTreeSearchUseCaseFactory",677:"MyOffersPurchasesPage",701:"AlertsShowAds",736:"reactstrap-Tooltip",737:"UserRating",796:"LocationUseCasesFactory",861:"SettingsAccountTypePageLanding",899:"PrivacySummary",925:"GetListingTrackingSearchUseCaseFactory",974:"CardStatusPage",993:"PageStoreDescription",1e3:"SaveOnboardingSearchUseCase",1012:"GetSalesCountUserUseCaseFactory",1018:"GetHomeSeoCategoriesUseCaseFactory",1052:"MyAdUseCasesFactory",1077:"GetPublicProfileUserUseCaseFactory",1081:"SearchPTACategoriesUseCaseFactory",1098:"RemoveFilteredProvincesSearchUseCase",1104:"ClassifiedPost",1178:"DoDeleteAccountUserUseCaseFactory",1181:"GetRecentlyRelatedFavoriteAdsSearchUseCase",1268:"VerifiedAccount",1297:"AutoRenew",1300:"VerificationUseCasesFactory",1359:"ListingPersonalizedAds",1384:"GetFotocasaBannerAdDetailUseCaseFactory",1418:"GetStoreAdListSearchUseCaseFactory",1476:"GetAdDraftLocalStorageAdCreationUseCase",1520:"GetReportUserReasonsMessagingUseCase",1521:"DeleteFavoriteAdUserUseCaseFactory",1529:"GetAdsWithShippingAvailableSearchUseCase",1535:"GetHomeCrosslinksSeoUseCaseFactory",1566:"GetDefinitionByPageSEOUseCaseFactory",1581:"GetRecommendedAdsSearchUseCase",1652:"GetLastBankAccountWalletUseCase",1754:"CookiesPolicy",1813:"GetSeoProductSchemaSearchUseCase",1820:"GetAdQualityRuleByCategoryIdAdCreationUseCase",1831:"AuthenticationUseCasesFactory",1841:"SettingsDataPage",1842:"GetPageSeoUseCaseFactory",1865:"CreditsPurchases",1876:"FavoriteListingPage",1888:"GetFormByCategoryIdAdCreationUseCase",1889:"ClassifiedPostVerification",1927:"ua-parser",1935:"SettingsBankAccountsPage",1974:"GetRecommendedPriceAdCreationUseCase",2062:"CallContactDebuggerTrackingUseCaseFactory",2134:"GetCategoryAggregationSearchUseCase",2188:"InsuranceCars",2225:"UpdateBankAccountWalletUseCase",2312:"SocialLoginAuthenticationUseCaseFactory",2341:"Transparency",242 ...
#     https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_640x480 640w,
#     https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_596x447 596w,
#     https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_432x320 432w
#     " title="TESLA - Model Y, Precio financiado sujeto a financiaciÓn mÍnima de 30.000€ en 72 meses y permanencia de 24 meses
#
#  subjecte a finanÇament mÍnim de 30.000 € en 72 mesos i permenencia 24 mesos"/></picture></div></li></ul></div></div><p class="ma-SharedSliderCounter"><span class="sui-AtomIcon sui-AtomIcon--size-extraSmall sui-AtomIcon--color-currentColor"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="m15.9 5.7-1.4-2.2c-.1-.3-.5-.5-.8-.5h-3.6c-.3 0-.7.2-.8.5L7.8 5.7H4.6c-.9 0-1.6.7-1.6 1.5v10.2c0 .9.7 1.6 1.6 1.6h15.3c.9 0 1.5-.7 1.5-1.5V7.2c0-.9-.7-1.6-1.5-1.6h-4zm1.2-2h2.8c2 0 3.5 1.6 3.5 3.5v10.2c0 2-1.6 3.5-3.5 3.5H4.6c-2 0-3.6-1.6-3.6-3.5V7.2c0-1.9 1.6-3.5 3.6-3.5h2.2l.8-1.3C8.1 1.5 9.1 1 10.1 1h3.6c1 0 2 .5 2.5 1.4l.9 1.3zM15 12.5c0-1.7-1.3-3-3-3s-3 1.3-3 3 1.3 3 3 3 3-1.3 3-3zm2 0c0 2.8-2.2 5-5 5s-5-2.2-5-5 2.2-5 5-5 5 2.2 5 5zm1.9-3.1c.8 0 1.5-.7 1.5-1.5s-.7-1.5-1.5-1.5-1.5.7-1.5 1.5.7 1.5 1.5 1.5z"></path></svg></span></span>1 / 19</p></div><header class="ma-AdDetail-headerListing"></header></div><h1 class="ma-SharedText ma-AdDetail-title ma-AdDetail-title-size-heading-m ma-AdDetail-title ma-SharedText--m ma-SharedText--black" style="text-align:left;font-weight:400">TESLA - Model Y<div class="ma-AdDetail-favoriteButtonWrapper"><div aria-disabled="true" aria-label="Guardar anuncio como favorito" aria-pressed="false" class="ma-AdDetail-favorite-button" data-testid="AD_DETAIL_FAVORITE_BUTTON" role="button" tabindex="0"><span class="sui-AtomIcon sui-AtomIcon--size-medium sui-AtomIcon--color-primary"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.8 6.4c-.4.6-1.2.6-1.6 0-.9-1.3-2-1.9-3.5-1.9-2.3 0-4.2 2-4.2 4.5 0 .9.3 1.8.8 2.7.6.9 1.4 1.9 2.7 3.3l1.9 1.9c.3.2 1.1 1 1.2 1.2.4.4.7.6.8.8l.6.6c.2.2.6.2.9 0l.6-.6.8-.8c.2-.1 1-.9 1.2-1.2 1-1 1.7-1.6 1.9-1.9 1.3-1.3 2.2-2.3 2.7-3.3.6-1 .8-1.8.8-2.7 0-2.6-1.8-4.5-4.2-4.5-1.3-.1-2.5.6-3.4 1.9zm3.5-3.9c3.5 0 6.2 2.9 6.2 6.5 0 1.3-.4 2.5-1.1 3.7-.7 1.1-1.6 2.2-3 3.7l-1.9 1.9c-.3.2-1.1 1-1.2 1.2-.4.4-.7.6-.8.7l-.6.6c-1 1-2.7 1-3.7 0l-.6-.6-.8-.8c-.2-.1-1-.9-1.2-1.2-1-1-1.7-1.6-2-1.9-1.4-1.5-2.4-2.6-3-3.7-.7-1.1-1.1-2.3-1.1-3.6 0-3.6 2.7-6.5 6.2-6.5 1.7 0 3.2.6 4.3 1.8 1.2-1.2 2.6-1.8 4.3-1.8z"></path></svg></span></span></div><p class="ma-SharedText ma-AdDetail-favoriteButtonWrapper-Stat ma-SharedText--s ma-SharedText--black" style="text-align:left;font-weight:400">4</p></div></h1><div class="ma-ContentAdDetail-priceWrapper"><div class="ma-AdMultiplePrice"><p class="ma-AdMultiplePrice-priceBlock"><span class="ma-AdMultiplePrice-cashPriceTitle ma-AdMultiplePrice-cashPriceTitle--black">Precio al contado</span><span class="ma-AdPrice"><span class="ma-AdPrice-value ma-AdPrice-value--primary ma-AdPrice-value--heading--l">45.128 €<span aria-label="Bajada de precio" class="sui-AtomIcon sui-AtomIcon--size-medium sui-AtomIcon--color-currentColor" role="img"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M2.293 6.3a.982.982 0 0 1 1.414 0l4.831 4.96 2.97-3.048a1.67 1.67 0 0 1 1.184-.497c.443 0 .868.179 1.185.497l.007.007L20 14.496v-3.207c0-.566.448-1.026 1-1.026s1 .46 1 1.027v5.684C22 17.54 21.552 18 21 18h-5.538c-.553 0-1-.46-1-1.026 0-.567.447-1.027 1-1.027h3.124L12.692 9.9l-2.969 3.047a1.67 1.67 0 0 1-1.185.497 1.67 1.67 0 0 1-1.184-.497l-.007-.007-5.054-5.187c-.39-.4-.39-1.05 0-1.451Z" fill-rule="evenodd"></path></svg></span></span></span><span class="ma-AdPrice-previousValue ma-AdPrice-value--primary ma-AdPrice-value--heading--s">45.990 €</span></span><span class="ma-AdMultiplePrice-includeTaxes ma-AdMultiplePrice-includeTaxes--black">IVA Incluido</span></p><p class="ma-AdMultiplePrice-priceBlock"><span class="ma-AdMultiplePrice-financedPriceTitle ma-AdMultiplePrice-financedPriceTitle--gray">Precio financiado</span><span class="ma-AdPrice"><span class="ma-AdPrice-value ma-AdPrice-value--gray ma-AdPrice-value--heading--l">42.128 €</span></span><button class="sui-AtomButton sui-AtomButt ...
#
#  subjecte a finanÇament mÍnim de 30.000 € en 72 mesos i permenencia 24 mesos</p><section class="ma-AdStatistics"><p class="ma-SharedText ma-AdDetail-time ma-SharedText--s ma-SharedText--gray" style="text-align:left;font-weight:400">Publicado el 19/02/2026 a las 15:14 </p><p class="ma-SharedText ma-AdDetail-time ma-SharedText--s ma-SharedText--gray" style="text-align:left;font-weight:400">Editado hoy a las 14:15</p></section><div class="ma-AdCarfax"><h3 class="ma-SharedText ma-AdCarfax-title ma-SharedText--m ma-SharedText--black" style="text-align:left;font-weight:500">Antes de comprar un coche</h3><picture class="ma-SharedImage"><img alt="Logo de Carfax" decoding="auto" fetchpriority="auto" loading="lazy" src="https://scm-milanuncios-frontend-pro.milanuncios.com/statics/images/search/carfax-logo.svg" title="" width="120"/></picture><p class="ma-SharedText ma-AdCarfax-description ma-SharedText--s ma-SharedText--gray" style="text-align:left;font-weight:400">Comprueba que todo está bien: daños y accidentes, lecturas de kilometraje, inspecciones, etc. y accede al historial detallado del vehículo con el servicio CARFAX de Milanuncios.</p><p class="ma-SharedText ma-AdCarfax-info ma-SharedText--xs ma-SharedText--black" style="text-align:left;font-weight:400">Necesitarás saber la matrícula del coche para esta gestión</p><a class="sui-AtomButton sui-AtomButton--primary sui-AtomButton--outline sui-AtomButton--center sui-AtomButton--large sui-AtomButton--link sui-AtomButton--rounded ma-AdCarfax-button" href="https://www.carfax.eu/es/partner/milanuncios?make=Tesla&amp;pic=https://images.milanuncios.com/api/v1/ma-ad-media-pro/images/9900f3a6-6275-43fb-9af8-1fc86dee2cfc?rule=detail_640x480_jpeg#utm_source=milanuncios.com&amp;utm_medium=website&amp;utm_content=website_button&amp;utm_campaign=classifieds_integrations&amp;ct_pm=model_1&amp;ct_st=dealer&amp;ct_ts=consumer" rel="noopener" target="_blank" title="download-report"><span class="sui-AtomButton-inner"><span class="sui-AtomButton-content">Descargar informe</span></span></a></div><div class="ma-AdDetailSellerCarousel"><section aria-labelledby="ma-SharedCarouselV2-title" aria-roledescription="Carrusel" class="ma-SharedCarouselV2"><div class="ma-SharedCarouselV2-header"><div class="ma-SharedCarouselV2-titleContent"><div class="ma-SharedCarouselV2-titleWrapper"><h2 class="ma-SharedText ma-SharedCarouselV2-title ma-SharedText--m ma-SharedText--black" id="ma-SharedCarouselV2-title" style="text-align:left;font-weight:500" tabindex="0">AUTOKOLECCIO tiene 144 anuncios</h2></div></div><nav aria-label="Navegación del carrusel" class="ma-SharedCarouselV2-navigation"><button aria-label="Anterior" class="sui-AtomButton sui-AtomButton--neutral sui-AtomButton--solid sui-AtomButton--center sui-AtomButton--large sui-AtomButton--disabled sui-AtomButton--rounded" disabled=""><span class="sui-AtomButton-inner"><span class="sui-AtomButton-content"><span class="sui-AtomIcon sui-AtomIcon--size-large sui-AtomIcon--color-currentColor"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15.589 7.669 11.69 12l3.898 4.331a1 1 0 1 1-1.487 1.338l-4.5-5a1 1 0 0 1 0-1.338l4.5-5a1 1 0 1 1 1.487 1.338z"></path></svg></span></span></span></span></button><button aria-label="Siguiente" class="sui-AtomButton sui-AtomButton--neutral sui-AtomButton--solid sui-AtomButton--center sui-AtomButton--large sui-AtomButton--rounded"><span class="sui-AtomButton-inner"><span class="sui-AtomButton-content"><span class="sui-AtomIcon sui-AtomIcon--size-large sui-AtomIcon--color-currentColor"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.3 7.7c-.4-.4-.3-1 .1-1.4s1-.3 1.4.1l4.5 5c.3.4.3 1 0 1.3l-4.5 5c-.4.4-1 .4-1.4.1s-.4-1-.1-1.4l3.9-4.3-3.9-4.4z"></path></svg></span></span></span></span></button></nav></div><div class="ma-SharedCarouselV2-wrapper" tabindex="0"><ul aria-atomic="false" aria-live="polite" class ...

# %%
elem = soup.select("#app > div.ma-LayoutBasic > div.ma-AdvertisementPageLayout.ma-AdvertisementPageLayout-justify--center > div.ma-AdvertisementPageLayout-center > div.ma-LayoutBasic-content.a-AdDetail > div > main > article > section > div > div.ma-ContentAdDetail-priceWrapper > div > p:nth-child(1) > span.ma-AdPrice > span.ma-AdPrice-value.ma-AdPrice-value--primary.ma-AdPrice-value--heading--l")

# %%
elem
# Out:
# [<span class="ma-AdPrice-value ma-AdPrice-value--primary ma-AdPrice-value--heading--l">45.128 €<span aria-label="Bajada de precio" class="sui-AtomIcon sui-AtomIcon--size-medium sui-AtomIcon--color-currentColor" role="img"><span><svg aria-hidden="true" role="presentation" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M2.293 6.3a.982.982 0 0 1 1.414 0l4.831 4.96 2.97-3.048a1.67 1.67 0 0 1 1.184-.497c.443 0 .868.179 1.185.497l.007.007L20 14.496v-3.207c0-.566.448-1.026 1-1.026s1 .46 1 1.027v5.684C22 17.54 21.552 18 21 18h-5.538c-.553 0-1-.46-1-1.026 0-.567.447-1.027 1-1.027h3.124L12.692 9.9l-2.969 3.047a1.67 1.67 0 0 1-1.185.497 1.67 1.67 0 0 1-1.184-.497l-.007-.007-5.054-5.187c-.39-.4-.39-1.05 0-1.451Z" fill-rule="evenodd"></path></svg></span></span></span>]

# %%
elem[0].text.strip() # Obtenemos el precio del Tesla
# Out:
# '45.128\xa0€'

# %%
precio = elem[0].text.strip().replace('\xa0€', '').replace('.', '')

# %%
precio = int(precio)

# %%
precio
# Out:
# 45128

# %% [markdown]
# ### Ejemplo 2 Otro Tesla

# %%
url = "https://www.milanuncios.com/otros-coches-de-segunda-mano/tesla-model-y-546858128.htm"

# %%
response = requests.get(url, headers=cabecera)
soup = bs4.BeautifulSoup(response.text, 'lxml')

# %%
elem = soup.select("#app > div.ma-LayoutBasic > div.ma-AdvertisementPageLayout.ma-AdvertisementPageLayout-justify--center > div.ma-AdvertisementPageLayout-center > div.ma-LayoutBasic-content.ma-AdDetail > div > main > article > section > div > div.ma-ContentAdDetail-priceWrapper > div > p > span.ma-AdPrice > span")

# %%
elem[0].text.strip() # Obtenemos el precio del Tesla
precio = elem[0].text.strip().replace('\xa0€', '').replace('.', '')
precio = int(precio)
precio
# Out:
# 34990

# %% [markdown]
# ### Ejemplo 3 Oscaro

# %%
urlOscaroXenon1 = "https://www.oscaro.es/bombilla-de-xenon-hella-8gs-009-028-111-5720751-10010-p"

# %%
urlOscarVision2 = "https://www.oscaro.es/lampara-philips-5552130-6853538-1457-p#/"

# %%
response1 = requests.get(urlOscaroXenon1, headers=cabecera)
soup1 = bs4.BeautifulSoup(response1.text, 'lxml')

# %%
response2 = requests.get(urlOscarVision2, headers=cabecera)
soup2 = bs4.BeautifulSoup(response2.text, 'lxml')

# %%
elem1 = soup1.select("#root > main > div.container.product-page > article > div.product-buy > div > div > p > span")

# %%
elem2 = soup2.select("#root > main > div.container.product-page > article > div.product-buy > div > div > p > span")

# %%
elem1[0].text.strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 elem1[0].text.strip()
#
# IndexError: list index out of range

# %%
elem2[0].text.strip()
# Out:
# '1,70 â\x82¬'

# %%
precio1 = elem1[0].text.strip().replace(' â\x82¬', '')
precio1
# Out:
# '53,90'

# %%
precio2 = elem2[0].text.strip().replace(' â\x82¬', '')
precio2
# Out:
# '1,70'
