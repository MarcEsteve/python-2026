# %% [markdown]
# # Abrir el archivo PDF en modo binario

# %%
import PyPDF2

# %%
rutaPDF = "C:/Users/artha/OneDrive/Escritorio/AKKODIS/python-rda/05_xlsx_docx_pdf/tecnologias_emergentes.pdf"

# %%
with open(rutaPDF, "rb") as pdfFile:
    lector = PyPDF2.PdfReader(pdfFile)
    
    # Número de páginas del PDF
    num_paginas = len(lector.pages)
    print(f"El PDF tiene {num_paginas} páginas.\n")

    # Leer el contenido de la primera página
    pagina = lector.pages[0]  # Acceder a la primera página (índice 0)
    texto = pagina.extract_text()
    print("Texto extraído de la primera página:")
    print(texto)
# Out:
# El PDF tiene 6 páginas.
#
# Texto extraído de la primera página:
# Tecnologías Emergentes 2025
# Introducción
# “El año 2025 marcará un punto de inflexión en la evolución de diversas tecnologías
# emergentes .”
# Con avances significativos en inteligencia artificial, computación cuántica, biotecnología y
# sostenibilidad, las empresas y la sociedad en general experimentarán cambios
# transformadores.
# Este documento explora las principales innovaciones que se esperan en los próximos años y
# su impacto en la economía global.

# %%
# Abrir el archivo en modo binario y mantenerlo abierto durante toda la lectura
with open(rutaPDF, "rb") as pdfFile:
    lector = PyPDF2.PdfReader(pdfFile)  # Usa PdfReader en lugar de PdfFileReader
    
    # Número de páginas del PDF
    num_paginas = len(lector.pages)
    print(f"El PDF tiene {num_paginas} páginas.\n")

    # Iteramos la lectura del PDF página por página
    for i in range(num_paginas):
        pagina = lector.pages[i]  # Acceder a cada página
        texto = pagina.extract_text()  # Extraer el texto de la página
        
        print(f"\nTexto extraído de la página {i + 1}:")
        print(texto if texto else "⚠ No se pudo extraer texto de esta página.")
# Out:
# El PDF tiene 6 páginas.
#
#
# Texto extraído de la página 1:
# Tecnologías Emergentes 2025
# Introducción
# “El año 2025 marcará un punto de inflexión en la evolución de diversas tecnologías
# emergentes .”
# Con avances significativos en inteligencia artificial, computación cuántica, biotecnología y
# sostenibilidad, las empresas y la sociedad en general experimentarán cambios
# transformadores.
# Este documento explora las principales innovaciones que se esperan en los próximos años y
# su impacto en la economía global.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Texto extraído de la página 2:
# Inteligencia Artificial (IA) y Automatización
# La inteligencia artificial seguirá revolucionando sectores como la salud, la educación y la
# industria. Modelos avanzados de IA generativ a permitirán una interacción más natural entre
# humanos y máquinas, mientras que la automatización impulsada por IA optimizará la
# eficiencia en tareas complejas. Se espera que:
#  Las herramientas de IA se integren más en el ámbito educativo, personalizando el
# aprendizaje.
#  La robótica avanzada en la medicina mejore los procedimientos quirúrgicos y la
# atención al paciente.
#  Los algoritmos predictivos permitan una mejor gestión de recursos en sectores como
# la energía y el transporte.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Texto extraído de la página 3:
# Computación Cuántica
# La computación cuántica avanza a pasos agigantados, con empresas tecnológicas invirtiendo
# en el desarrollo de procesadores cuánticos más estables y accesibles. En 2025, se prevé:
#  Mayor integración de la computación cuántica en la resolución de problemas
# logísticos y financieros.
#  Avances en criptografía cuántica para mejorar la seguridad en la transmisión de datos.
#  Simulaciones moleculares más precisas, acelerando el descubrimiento de nuevos
# materiales y fármacos.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Texto extraído de la página 4:
# Biotecnologí a y Medicina Personalizada
# El desarrollo de la biotecnología permitirá tratamientos más efectivos y personalizados para
# diversas enfermedades. La combinación de IA y biología sintética posibilitará avances como:
#  Terapias génicas más accesibles y con menores efectos secundarios.
#  Diagnósticos médicos en tiempo real mediante sensores y dispositivos portátiles.
#  Impresión 3D de tejidos y órganos para mejorar la disponibilidad de trasplantes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Texto extraído de la página 5:
# Sostenibilidad y Energías Renovables
# Con la crisis climática en el centro del debate mundial, 2025 será un año clave para la
# transición energética y el desarrollo de soluciones más sostenibles. Entre los avances más
# esperados destacan:
#  Mayor eficiencia en el almacenamiento de energía con baterías de  nueva generación.
#  Uso masivo de hidrógeno verde como fuente de energía limpia.
#  Aplicación de nanotecnología para mejorar la captura y reutilización de CO2.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Texto extraído de la página 6:
# Conclusión
# El impacto de estas tecnologías en la sociedad dependerá de cómo sean reguladas e
# implementadas. La colaboración entre gobiernos, empresas y científicos será clave para
# asegurar un desarrollo tecnológico ético y sostenible. 2025 promete ser un año de
# innovaciones que cambiarán la forma en que vivimos y trabajamos, abrie ndo nuevas
# oportunidades y desafíos para el futuro.
