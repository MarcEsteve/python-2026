# %% [markdown]
# # 🐭 Librería: pyautogui (ratón)

# %%
import pyautogui #pip install pyautogui

# %%
pyautogui.size() # Devuelve el tamaño de la pantalla
# Out:
# Size(width=2560, height=1600)

# %%
pyautogui.position()
# Out:
# Point(x=5373, y=607)

# %%
pyautogui.moveTo(5135, 881)

# %%
pyautogui.moveTo(5135, 881, duration=1)

# %%
pyautogui.moveTo(5135, 881, duration=2, tween=pyautogui.easeInOutQuad)

# %%
pyautogui.moveRel(500, 300)

# %%
pyautogui.moveRel(100, 100, duration=1)

# %%
pyautogui.click(5441, 331)

# %%
pyautogui.doubleClick(5373, 607)

# %%
pyautogui.dragRel(200, 200, duration=1)
pyautogui.dragRel(0, -200)
pyautogui.dragRel(-200, 0)
